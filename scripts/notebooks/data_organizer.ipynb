# %% [markdown]
# # Data Organizer
#
# A collection of code-snippets to help organize and manage MIAPPE-compliant metadata tables.

# %%
# Example to map an ppeo excel file into JSON-LD format

import pandas as pd
import json



PATH = r'/home/gryvity/Desktop/workstation/lab/MIAPPEx/scripts/notebooks/test_data/example_01_v1.1_ext.xlsx'

standard_sheet_names = ['Investigation', 
                        'Datafile', 
                        'Person', 
                        'Study', 
                        'Observation Unit', 
                        'Observed Variable', 
                        'Biological Material', 'Environment', 
                        'Factor', 
                        'Event', 
                        'Sample']




# Load the Excel file sheets into a dictionary of DataFrames
sheets = pd.read_excel(PATH, sheet_name=None).keys()



# Now read for each sheet all column names and sort them into a dictionary
column_names = {}
for sheet in sheets:
    if sheet in standard_sheet_names:
        df = pd.read_excel(PATH, sheet_name=sheet)
        column_names[sheet] = list(df.columns)[1:]


print(json.dumps(column_names, indent=4))
# Out:
# {
#     "Investigation": [
#         "Investigation unique ID",
#         "Investigation title",
#         "Investigation description",
#         "Submission date",
#         "Public release date",
#         "License",
#         "MIAFPE version",
#         "Associated publication",
#         "Metadata file version"
#     ],
#     "Person": [
#         "Study unique ID",
#         "Person name",
#         "Person email",
#         "Person ID",
#         "Person role",
#         "Person affiliation"
#     ],
#     "Study": [
#         "Study unique ID",
#         "Study title",
#         "Study description",
#         "Start date of study",
#         "End date of study",
#         "Contact institution",
#         "Geographic location (country)",
#         "Experimental site name",
#         "Geographic location (latitude)",
#         "Geographic location (longitude)",
#         "Geographic location (altitude)",
#         "Description of the experimental design",
#         "Type of experimental design",
#         "Observation unit level hierarchy",
#         "Observation unit description",
#         "Description of growth facility",
#         "Type of growth facility",
#         "Cultural practices",
#         "Map of experimental design"
#     ],
#     "Observation Unit": [
#         "Study unique ID",
#         "Observation unit ID",
#         "Feature Of Interest",
#         "Observation unit type",
#         "External ID",
#         "Spatial distribution",
#         "Observation Unit factor value"
#     ],
#     "Observed Variable": [
#         "Link to unique ID",
#         "Variable ID",
#         "Variable name",
#         "Variable accession number",
#         "Trait",
#         "Trait accession number",
#         "Method",
#         "Method accession number",
#         "Method description",
#         "Reference associated to the method",
#         "Scale",
#         "Scale accession number",
#         "Time scale",
#         "Sensor ID",
#         "Sensor location",
#         "Platform ID",
#         "Platform Location",
#         "Obervation Unit ID",
#         "Results"
#     ],
#     "Biological Material": [
#         "Study unique ID",
#         "Biological material ID",
#         "Organism",
#         "Genus",
#         "Species",
#         "Infraspecific name",
#         "Biological material latitude",
#         "Biological material longitude",
#         "Biological material altitude",
#         "Biological material coordinates uncertainty",
#         "Biological material preprocessing",
#         "Material source ID (Holding institute/stock centre, accession)",
#         "Material source DOI",
#         "Material source latitude",
#         "Material source longitude",
#         "Material source altitude",
#         "Material source coordinates uncertainty",
#         "Material source description"
#     ],
#     "Environment": [
#         "Study unique ID",
#         "Environment parameter",
#         "Environment parameter value"
#     ],
#     "Event": [
#         "Study unique ID",
#         "Observation unit ID",
#         "Event type",
#         "Event accession number",
#         "Event description",
#         "Event date"
#     ],
#     "Sample": [
#         "Observation unit ID",
#         "Sample ID",
#         "Plant structure development stage",
#         "Plant anatomical entity",
#         "Sample description",
#         "Collection date",
#         "External ID"
#     ]
# }

# %%
import os 
import pandas as pd 
import re
from collections import defaultdict


class MIAPPExDataModel:
    """
    Docstring for MIAPPExDataModel

    Definitions for the DataModel
    """
    def __init__(self):

        self._context = {
            'ppeo' : 'http://purl.org/ppeo/',
            'sosa' : 'http://www.w3.org/ns/sosa/',
            'ssn'  : 'http://www.w3.org/ns/ssn/'
        }

        self._standard_sheet_names = [r'Investigation', 
                                      r'Data*File', 
                                      r'Person', 
                                      r'Study', 
                                      r'Observation*Unit', 
                                      r'Observed*Variable', 
                                      r'Biological*Material', 
                                      r'Environment', 
                                      r'*Factor', 
                                      r'Event', 
                                      r'Sample']
        
        self._sosa_sheet_names = [r'System',
                                  r'Sensor',
                                  r'Platform',
                                  r'Feature*Of*Interest',
                                  r'Procedure']
        
        self.std_sheets = self._standard_sheet_names + self._sosa_sheet_names
        
        self._classes_miappe = {
            'Investigation': 'ppeo:Investigation',
            'DataFile': 'ppeo:Datafile',
            'Person': 'ppeo:Person',
            'Study': 'ppeo:Study',
            'ObservationUnit': 'ppeo:ObservationUnit',
            'ObservedVariable': 'ppeo:ObservedVariable',
            'BiologicalMaterial': 'ppeo:BiologicalMaterial',
            'Environment': 'ppeo:Environment',
            'Factor': 'ppeo:Factor',
            'Event': 'ppeo:Event',
            'Sample': 'ppeo:Sample'
        }
        self._classes_sosassn = {
            'System': 'ssn:System',
            'Sensor': 'sosa:Sensor',
            'Platform': 'sosa:Platform',
            'FeatureOfInterest': 'sosa:FeatureOfInterest',
            'Procedure': 'sosa:Procedure',
            'Input' : 'ssn:Input',
            'Output' : 'ssn:Output'
        }

        self._obj_properties_miappe = {
            'name_01': {
                'context': 'ppeo',
                'accession': '',
                'domain': [],
                'range': [],
            }
        }
        self._obj_properties_sosassn = {}


        self._Individuals = {
            "example_01" : {
                "type": "exampleType", 
                "accession": "http://example.org/individuals/example"
            }
           
        }

    def load_ontology(self, path):
        pass
                                  

class MIAPPExXLSX(MIAPPExDataModel):
    
    """
    Docstring for MIAPPExXLSX

    """     
    def __init__(self, path):
        super().__init__()
        self.path = path
        self.validate_format()

        # Loading Data
        self.data = self.load()
        self.sheets = self.get_sheet_names()
        
        # Get MIAPPE Version
        self.version = self.get_version()

        # Collect Further Structure Information
        self.sheet_info = {}
        
        self.get_properties()
        self.get_sheet_info()

    # Loading File
    def validate_format(self):
        # Validate file format based on extension
        self.format = os.path.splitext(self.path)[-1]
        if self.format != '.xlsx':
            raise ValueError(f'Unsupported file format: {self.format}')
        
    def load(self):
        # Until now only Excel format is supported
        if self.format == '.xlsx':
            return pd.read_excel(self.path, sheet_name=None)
        else:
            raise ValueError(f'Unsupported file format: {self.format}')
        
    # Get the Version
    def get_version(self):
        # Get MIAPPE version from the Investigation sheet
        if 'Investigation' in self.data:
            if 'Field' in self.data['Investigation'].columns:
                return 1.1
            else:
                return 1.2
        else:
            raise ValueError('Investigation sheet not found in the data.')

    

    # Organizing On Sheet Level
    def get_sheet_names(self):
        # Get sheet names from the Excel file and returns a dictionary with standardized names
        sheets = defaultdict(str)
        for sheet_name in self.data.keys():
            stdname =  self.standardize_sheet_name(sheet_name)
            if stdname:
                sheets[sheet_name] = stdname
            else:
                sheets[sheet_name] = 'unknown'  # Mark unknown sheets
        return sheets

    def standardize_sheet_name(self, sheet_name):
        # Standardize sheet names based on predefined patterns
        if 'appendix' in sheet_name.lower():
            return 'appendix'
        elif 'readme' in sheet_name.lower():
            return 'readme'
        for std in self.std_sheets:
            pattern = re.compile(rf'^{std.replace("*", ".*")}$', re.IGNORECASE)
            if pattern.match(sheet_name):
                return std.replace("*", "")
        return False

    # Organizing on Property Level
    def get_properties(self):
        # Get column names for a given sheet
        self.structure = {}
        if self.version == 1.1:
            i = 1
        else:
            i = 0
        for sheet in self.sheets.keys():
            # Only get columns if we have not a readme or appendix sheet
            if self.sheets[sheet] in ['readme', 'appendix']:
                continue
            df = pd.read_excel(self.path, sheet_name=sheet)
            self.structure[sheet] = list(df.columns)[i:]

    def get_sheet_info(self):
        # Gets additional information
        self.sheet_info = {}
        data_pivot = None
        for sheet in self.sheets.keys():
            # Only get columns if we have not a readme or appendix sheet
            if self.sheets[sheet] in ['readme', 'appendix']:
                continue
                

            if self.version == 1.1:
                # Identify the row where the word 'value' appears in the first column
                for i,n in enumerate(self.data[sheet].iloc[:, 0]):
                    if 'value' in str(n).lower():
                        data_pivot = (i, 1)
                        break
            else:
                data_pivot = (0, 0)

           
            self.sheet_info[sheet] = {
                'num_rows': self.data[sheet].shape[0],
                'num_columns': self.data[sheet].shape[1],
                'data_pivot' : data_pivot,
                'data': self.data[sheet].iloc[data_pivot[0]:, data_pivot[1]:].reset_index(drop=True)
            }
            print(f"Sheet: {sheet}, Info: {self.sheet_info[sheet]}")
        


  
        
    

# if __name__ == "__main__":       
base_path = "/home/gryvity/Desktop/workstation/lab/MIAPPEx/scripts/notebooks/"
example_files = [os.path.join(base_path, 'test_data/example_01_v1.1_ext.xlsx'),
                     os.path.join(base_path, 'test_data/example_02_v1.1_ext.xlsx'),
                     os.path.join(base_path, 'test_data/example_01_v1.2.xlsx'),
                     os.path.join(base_path, 'test_data/example_02_v1.2.xlsx')]
    

picked_example = example_files[2]


MIAPPEx_data = MIAPPExXLSX(picked_example)
# Out:
# Sheet: Investigation, Info: {'num_rows': 1, 'num_columns': 9, 'data_pivot': (0, 0), 'data':                    investigationId  \
# 0  https://doi.org/10.15454/IASSTN
#
#                                   investigationTitle  \
# 0  A multi-site experiment in a network of Europe...
#
#                             investigationDescription submissionDate  \
# 0  This dataset comes from the European Union pro...     2018-10-10
#
#   publicReleaseDate       license  miappeVersion  associatedPublication  \
# 0        2019-03-27  CC BY-SA 4.0            1.2                    NaN
#
#                                    variablesOntology
# 0  The file 12a-Info-EIPO-Environmental_Traits.cs...  }
# Sheet: Study, Info: {'num_rows': 19, 'num_columns': 19, 'data_pivot': (0, 0), 'data':    studyId                           studyTitle  \
# 0    Gai12                Biogemma Gaillac 2012
# 1    Gai13                Biogemma Gaillac 2013
# 2    Gra13               Biogemma Graneros 2013
# 3    Ner11                  Biogemma Nerac 2011
# 4    Ner12                  Biogemma Nerac 2012
# 5    Ner13                  Biogemma Nerac 2013
# 6    Cra12                     KWS Caracal 2012
# 7    Kar11                   KWS Karlsruhe 2011
# 8    Kar12                   KWS Karlsruhe 2012
# 9    Kar13                   KWS Karlsruhe 2013
# 10   Mur13                      KWS Murony 2013
# 11   Mar13             MTA_ATK Martonvasar 2013
# 12   Cam11             Syngenta Campagnola 2011
# 13   Cam12             Syngenta Campagnola 2012
# 14   Cam13             Syngenta Campagnola 2013
# 15   Deb11               Syngenta Debrecen 2011
# 16   Deb12               Syngenta Debrecen 2012
# 17   Deb13               Syngenta Debrecen 2013
# 18   Bol12  University_of_Bologna Cadriano 2012
#
#                                      studyDescription studyStartDate  \
# 0   Maize European phenotyping network (DROPS proj...     2012-05-14
# 1   Maize European phenotyping network (DROPS proj...     2013-05-13
# 2   Maize European phenotyping network (DROPS proj...     2013-11-13
# 3   Maize European phenotyping network (DROPS proj...     2011-05-13
# 4   Maize European phenotyping network (DROPS proj...     2012-05-27
# 5   Maize European phenotyping network (DROPS proj...     2013-05-15
# 6   Maize European phenotyping network (DROPS proj...     2012-05-21
# 7   Maize European phenotyping network (DROPS proj...     2011-05-04
# 8   Maize European phenotyping network (DROPS proj...     2012-05-10
# 9   Maize European phenotyping network (DROPS proj...     2013-04-17
# 10  Maize European phenotyping network (DROPS proj...     2013-05-21
# 11  Maize European phenotyping network (DROPS proj...     2013-05-14
# 12  Maize European phenotyping network (DROPS proj...     2011-05-10
# 13  Maize European phenotyping network (DROPS proj...     2012-05-17
# 14  Maize European phenotyping network (DROPS proj...     2013-06-14
# 15  Maize European phenotyping network (DROPS proj...     2011-05-13
# 16  Maize European phenotyping network (DROPS proj...     2012-05-21
# 17  Maize European phenotyping network (DROPS proj...     2013-05-23
# 18  Maize European phenotyping network (DROPS proj...     2012-05-17
#
#    studyEndDate            contactInst locationCountry     siteName  \
# 0    2012-10-27               Biogemma              FR      Gaillac
# 1    2013-10-25               Biogemma              FR      Gaillac
# 2    2014-04-03               Biogemma              CL     Graneros
# 3    2011-10-08               Biogemma              FR        Nerac
# 4    2012-10-10               Biogemma              FR        Nerac
# 5    2013-10-11               Biogemma              FR        Nerac
# 6    2012-09-18                   KWS               RO      Craiova
# 7    2011-10-18                   KWS               DE    Karlsruhe
# 8    2012-10-18                   KWS               DE    Karlsruhe
# 9    2013-10-20                   KWS               DE    Karlsruhe
# 10   2013-10-05                   KWS               HU       Murony
# 11   2012-10-31                    MTA              HU  Martonvasar
# 12   2011-10-04              Syngenta               IT   Campagnola
# 13   2012-10-04              Syngenta               IT   Campagnola
# 14   2013-11-13              Syngenta               IT   Campagnola
# 15   2011-10-11              Syngenta               HU     Debrecen
# 16   2012-10-05              Syngenta               HU     Debrecen
# 17   2013-10-11              Syngenta               HU     Debrecen
# 18   2012-08-29  University of Bologna              IT      Bologna
#
#     locationLatitude  locationLongitude  locationAltitude  \
# 0          43.900000           1.890000                49
# 1          43.900000           1.890000                49
# 2         -34.060000         -70.730000               841
# 3          44.170350           0.307320                40
# 4          44.170350           0.307320                40
# 5          44.170350           0.307320                40
# 6          44.115568          24.347763               101
# 7          49.100000           8.320000               100
# 8          49.100000           8.320000               100
# 9          49.100000           8.320000               100
# 10         46.780000          21.050000                85
# 11         47.310830          18.778330               110
# 12         45.171020           9.532240                49
# 13         45.171020           9.532240                49
# 14         45.171020           9.532240                49
# 15         47.181531          20.542382                81
# 16         47.181531          20.542382                81
# 17         47.181531          20.542382                81
# 18         44.933333          11.883333                 5
#
#                                        expeDesignDesc expeDesignType  \
# 0   Experimental sites of the DROPS project were l...  alpha lattice
# 1   Experimental sites of the DROPS project were l...  alpha lattice
# 2   Experimental sites of the DROPS project were l...  alpha lattice
# 3   Experimental sites of the DROPS project were l...  alpha lattice
# 4   Experimental sites of the DROPS project were l...  alpha lattice
# 5   Experimental sites of the DROPS project were l...  alpha lattice
# 6   Experimental sites of the DROPS project were l...  alpha lattice
# 7   Experimental sites of the DROPS project were l...  alpha lattice
# 8   Experimental sites of the DROPS project were l...  alpha lattice
# 9   Experimental sites of the DROPS project were l...  alpha lattice
# 10  Experimental sites of the DROPS project were l...  alpha lattice
# 11  Experimental sites of the DROPS project were l...  alpha lattice
# 12  Experimental sites of the DROPS project were l...  alpha lattice
# 13  Experimental sites of the DROPS project were l...  alpha lattice
# 14  Experimental sites of the DROPS project were l...  alpha lattice
# 15  Experimental sites of the DROPS project were l...  alpha lattice
# 16  Experimental sites of the DROPS project were l...  alpha lattice
# 17  Experimental sites of the DROPS project were l...  alpha lattice
# 18  Experimental sites of the DROPS project were l...  alpha lattice
#
#     obsUnitLevelHierarchy  obsUnitDesc growthFacilityDesc  growthFacilityType  \
# 0                     NaN          NaN              field                 NaN
# 1                     NaN          NaN              field                 NaN
# 2                     NaN          NaN              field                 NaN
# 3                     NaN          NaN              field                 NaN
# 4                     NaN          NaN              field                 NaN
# 5                     NaN          NaN              field                 NaN
# 6                     NaN          NaN              field                 NaN
# 7                     NaN          NaN              field                 NaN
# 8                     NaN          NaN              field                 NaN
# 9                     NaN          NaN              field                 NaN
# 10                    NaN          NaN              field                 NaN
# 11                    NaN          NaN              field                 NaN
# 12                    NaN          NaN              field                 NaN
# 13                    NaN          NaN              field                 NaN
# 14                    NaN          NaN              field                 NaN
# 15                    NaN          NaN              field                 NaN
# 16                    NaN          NaN              field                 NaN
# 17                    NaN          NaN              field                 NaN
# 18                    NaN          NaN              field                 NaN
#
#                                      culturalPractice  expeDesignMap
# 0   Maize European phenotyping network (DROPS proj...            NaN
# 1   Maize European phenotyping network (DROPS proj...            NaN
# 2   Maize European phenotyping network (DROPS proj...            NaN
# 3   Maize European phenotyping network (DROPS proj...            NaN
# 4   Maize European phenotyping network (DROPS proj...            NaN
# 5   Maize European phenotyping network (DROPS proj...            NaN
# 6   Maize European phenotyping network (DROPS proj...            NaN
# 7   Maize European phenotyping network (DROPS proj...            NaN
# 8   Maize European phenotyping network (DROPS proj...            NaN
# 9   Maize European phenotyping network (DROPS proj...            NaN
# 10  Maize European phenotyping network (DROPS proj...            NaN
# 11  Maize European phenotyping network (DROPS proj...            NaN
# 12  Maize European phenotyping network (DROPS proj...            NaN
# 13  Maize European phenotyping network (DROPS proj...            NaN
# 14  Maize European phenotyping network (DROPS proj...            NaN
# 15  Maize European phenotyping network (DROPS proj...            NaN
# 16  Maize European phenotyping network (DROPS proj...            NaN
# 17  Maize European phenotyping network (DROPS proj...            NaN
# 18  Maize European phenotyping network (DROPS proj...            NaN  }
# Sheet: Person, Info: {'num_rows': 28, 'num_columns': 6, 'data_pivot': (0, 0), 'data':     studyId            personName                 personEmail  \
# 0       NaN      Millet Emilie J.        emilie.millet@wur.nl
# 1       NaN         Pommier Cyril      cyril.pommier@inrae.fr
# 2       NaN           Buy Mélanie                         NaN
# 3       NaN            Nagel Axel                         NaN
# 4       NaN        Kruijer Willem                         NaN
# 5       NaN  Welz-Bolduan Therese                         NaN
# 6       NaN          Lopez Jeremy                         NaN
# 7       NaN        Cécile Richard                         NaN
# 8       NaN           Racz Ferenc                         NaN
# 9       NaN          Tanzi Franco                         NaN
# 10      NaN         Spitkot Tamas                         NaN
# 11      NaN     Canè Maria-Angela                         NaN
# 12      NaN       Negro Sandra S.                         NaN
# 13      NaN     Coupel-Ledru Aude  aude.coupel-ledru@inrae.fr
# 14      NaN   Nicolas Stéphane D.                         NaN
# 15      NaN       Palaffre Carine                         NaN
# 16      NaN         Bauland Cyril      cyril.bauland@inrae.fr
# 17      NaN       Praud Sébastien                         NaN
# 18      NaN          Ranc Nicolas                         NaN
# 19      NaN       Presterl Thomas                         NaN
# 20      NaN           Bedo Zoltan                         NaN
# 21      NaN      Tuberosa Roberto   roberto.tuberosa@unibo.it
# 22      NaN          Usadel Björn                         NaN
# 23      NaN      Charcosset Alain   alain.charcosset@inrae.fr
# 24      NaN   Van Eeuwijk Fred A.                         NaN
# 25      NaN          Draye Xavier   xavier.draye@uclouvain.be
# 26      NaN      Tardieu François   françois.tardieu@inrae.fr
# 27      NaN        Welcker Claude     claude.welcker@inrae.fr
#
#                       personId               personRole  \
# 0   ORCID: 0000-0002-2913-4892                   author
# 1   ORCID: 0000-0002-9040-8733                   author
# 2                          NaN                   author
# 3                          NaN                   author
# 4   ORCID: 0000-0001-7179-1733                   author
# 5                          NaN   author, data collector
# 6                          NaN                   author
# 7   ORCID: 0000-0003-0022-9692   author, data collector
# 8                          NaN                   author
# 9                          NaN  author, data collector
# 10                         NaN   author, data collector
# 11                         NaN   author, data collector
# 12                         NaN                   author
# 13  ORCID: 0000-0003-2097-5924                   author
# 14  ORCID: 0000-0003-0758-9930                   author
# 15                         NaN                   author
# 16  ORCID: 0000-0001-9916-2744                   author
# 17                         NaN                   author
# 18  ORCID: 0000-0002-2654-8125   author, data collector
# 19                         NaN                   author
# 20  ORCID: 0000-0001-9480-0532                   author
# 21  ORCID: 0000-0001-9143-9569                   author
# 22  ORCID: 0000-0003-0921-8041                   author
# 23  ORCID: 0000-0001-6125-503X                   author
# 24  ORCID: 0000-0003-3672-2921                   author
# 25  ORCID: 0000-0002-3637-3330                   author
# 26  ORCID: 0000-0002-7287-0094                   author
# 27  ORCID: 0000-0002-8275-1259                   author
#
#                                     personAffiliation
# 0   Biometris, Department of Plant Science, Wageni...
# 1                                         URGI, INRAE
# 2                                         URGI, INRAE
# 3                 IBMG, BioSC, RWTH Aachen University
# 4   Biometris, Department of Plant Science, Wageni...
# 5                                         KWS Saat SE
# 6                                           Limagrain
# 7                                            Biogemma
# 8                                            Syngenta
# 9                                      Syngenta Seeds
# 10  MTA ATK/ AI CAR HAS Martonvasar Brunszvik ut 2...
# 11  Department of Agricultural Sciences (DipSA), U...
# 12         GIGA-Medical Genomics, University of Liège
# 13                               LEPSE, INRA, SupAgro
# 14  GQE – Le Moulon, INRA, Univ. Paris-Sud, CNRS, ...
# 15                                  UE SMH Maïs, INRA
# 16  GQE – Le Moulon, INRA, Univ. Paris-Sud, CNRS, ...
# 17                                           Biogemma
# 18                                Syngenta France SAS
# 19                                        KWS Saat SE
# 20  MTA ATK/ AI CAR HAS Martonvasar Brunszvik ut 2...
# 21  Department of Agricultural Sciences (DipSA), U...
# 22                IBMG, BioSC, RWTH Aachen University
# 23  GQE – Le Moulon, INRA, Univ. Paris-Sud, CNRS, ...
# 24  Biometris, Department of Plant Science, Wageni...
# 25                                          ELIA, UCL
# 26                               LEPSE, INRA, SupAgro
# 27                               LEPSE, INRA, SupAgro  }
# Sheet: Data file, Info: {'num_rows': 19, 'num_columns': 6, 'data_pivot': (0, 0), 'data':     studyId                                dataFileLink  \
# 0       NaN                          0_data_outline.pdf
# 1       NaN                   1-Env_variables_daily.csv
# 2       NaN                10-Info-ObservedVariable.csv
# 3       NaN                           11-Info-Study.csv
# 4       NaN      12a-Info-EIPO-Environmental_Traits.csv
# 5       NaN              12b-Info-MIPO-Maize_traits.csv
# 6       NaN     2a-GrainYield_components_Plot_level.csv
# 7       NaN  2b-GrainYield_components_BLUEs_level-1.csv
# 8       NaN               3-Indices_GenoEnv_level-1.csv
# 9       NaN                    3b-Indices_Env_level.csv
# 10      NaN                   4-Genotypic_variables.csv
# 11      NaN                5-Leaf-Stages_Plot_level.csv
# 12      NaN                6-Plant_Ref_Geno_level-1.csv
# 13      NaN                 7a-Genotyping_50K_41722.csv
# 14      NaN                    7b-InfoSNP_50K_41722.csv
# 15      NaN              7c-Genotyping_50K_41722_nG.csv
# 16      NaN               8-Info-BiologicalMaterial.csv
# 17      NaN            9a-CrossValidation_Sets_Geno.csv
# 18      NaN             9b-CrossValidation_Sets_Exp.csv
#
#                                          dataFileDesc  dataFileVersion  \
# 0   This file contains the outline of the files or...              NaN
# 1   This file contains the environmental character...              NaN
# 2   List of phenotypic and environmental variables...              NaN
# 3   List of studies, including locations, used in ...              NaN
# 4   Ontology referenced in the "Observed Variable"...              NaN
# 5   Ontology referenced in the "Observed Variable"...              NaN
# 6   This file contains the raw phenotypic data per...              NaN
# 7   This file contains the genotypic means (Best L...              NaN
# 8   This file contains the environmental indices. ...              NaN
# 9   This file contains the mean environmental indi...              NaN
# 10  This file contains the genotypic variables use...              NaN
# 11  This file contains the number of leaves scored...              NaN
# 12  This file contains plant traits measured at th...              NaN
# 13  This file contains the 50K genotyping Matrix t...              NaN
# 14  This file contains the description of the 41,7...              NaN
# 15  This file contains the genotyping of 41,722 lo...              NaN
# 16  This file contains the description of the geno...              NaN
# 17  This file contains the 10 sampling sets of gen...              NaN
# 18  This file contains the 10 sampling sets of exp...              NaN
#
#                                        wasDerivedFrom               activity
# 0                                                 NaN                    NaN
# 1                                                 NaN                    NaN
# 2   12a-Info-EIPO-Environmental_Traits.csv ; 12b-I...  MIAPPE simplification
# 3                                                 NaN                    NaN
# 4                                                 NaN                    NaN
# 5                                                 NaN                    NaN
# 6                                                 NaN                    NaN
# 7             2a-GrainYield_components_Plot_level.tab                  BLUES
# 8                                                 NaN                    NaN
# 9                                                 NaN                    NaN
# 10                                                NaN                    NaN
# 11                                                NaN                    NaN
# 12                                                NaN                    NaN
# 13                                                NaN                    NaN
# 14                                                NaN                    NaN
# 15                                                NaN                    NaN
# 16                                                NaN                    NaN
# 17                                                NaN                    NaN
# 18                                                NaN                    NaN  }
# Sheet: Biological Material, Info: {'num_rows': 256, 'num_columns': 37, 'data_pivot': (0, 0), 'data':      studyId biologicalMaterialId  biologicalMaterialExtId         organism  \
# 0        NaN              11430_H                      NaN  NCBITAXON:4577
# 1        NaN                 A3_H                      NaN  NCBITAXON:4577
# 2        NaN               A310_H                      NaN  NCBITAXON:4577
# 3        NaN               A347_H                      NaN  NCBITAXON:4577
# 4        NaN               A374_H                      NaN  NCBITAXON:4577
# ..       ...                  ...                      ...              ...
# 251      NaN              W604S_H                      NaN  NCBITAXON:4577
# 252      NaN               W64A_H                      NaN  NCBITAXON:4577
# 253      NaN                 W9_H                      NaN  NCBITAXON:4577
# 254      NaN             W95115_H                      NaN  NCBITAXON:4577
# 255      NaN                Wf9_H                      NaN  NCBITAXON:4577
#
#     genus species infraspecificName  biologicalMaterialLatitude  \
# 0     Zea    mays             11430                         NaN
# 1     Zea    mays                A3                         NaN
# 2     Zea    mays              A310                         NaN
# 3     Zea    mays              A347                         NaN
# 4     Zea    mays              A374                         NaN
# ..    ...     ...               ...                         ...
# 251   Zea    mays             W604S                         NaN
# 252   Zea    mays              W64A                         NaN
# 253   Zea    mays                W9                         NaN
# 254   Zea    mays            W95115                         NaN
# 255   Zea    mays               Wf9                         NaN
#
#      biologicalMaterialLongitude  biologicalMaterialAltitude  ...  \
# 0                            NaN                         NaN  ...
# 1                            NaN                         NaN  ...
# 2                            NaN                         NaN  ...
# 3                            NaN                         NaN  ...
# 4                            NaN                         NaN  ...
# ..                           ...                         ...  ...
# 251                          NaN                         NaN  ...
# 252                          NaN                         NaN  ...
# 253                          NaN                         NaN  ...
# 254                          NaN                         NaN  ...
# 255                          NaN                         NaN  ...
#
#          Parent1  Parent1Synonym Parent1Holding  \
# 0     11430_usda      11430_usda           USDA
# 1        A3_inra         A3_inra           INRA
# 2      A310_inra       A310_inra           INRA
# 3      A347_inra       A347_inra           INRA
# 4      A374_inra       A374_inra           INRA
# ..           ...             ...            ...
# 251     W604S_uh        W604S_uh             UH
# 252    W64A_inra       W64A_inra           INRA
# 253      W9_inra         W9_inra           INRA
# 254  W95115_inra     W95115_inra           INRA
# 255     Wf9_inra        Wf9_inra           INRA
#
#                                     Parent1HoldingName Parent2  \
# 0    USDA,USA, United States Department of Agriculture  UH_007
# 1    INRA, France, Institut National de la Recherch...  UH_007
# 2    INRA, France, Institut National de la Recherch...  UH_007
# 3    INRA, France, Institut National de la Recherch...  UH_007
# 4    INRA, France, Institut National de la Recherch...  UH_007
# ..                                                 ...     ...
# 251               UH, Germany, University of Hohenheim  UH_007
# 252  INRA, France, Institut National de la Recherch...  UH_007
# 253  INRA, France, Institut National de la Recherch...  UH_007
# 254  INRA, France, Institut National de la Recherch...  UH_007
# 255  INRA, France, Institut National de la Recherch...  UH_007
#
#      Parent2Holding                    Parent2HoldingName  CodeID  Panel246  \
# 0                UH  UH, Germany, University of Hohenheim    3101       yes
# 1                UH  UH, Germany, University of Hohenheim    3102       yes
# 2                UH  UH, Germany, University of Hohenheim    3008       yes
# 3                UH  UH, Germany, University of Hohenheim    3013       yes
# 4                UH  UH, Germany, University of Hohenheim    3017       yes
# ..              ...                                   ...     ...       ...
# 251              UH  UH, Germany, University of Hohenheim    3254       yes
# 252              UH  UH, Germany, University of Hohenheim    3004       yes
# 253              UH  UH, Germany, University of Hohenheim    3047       yes
# 254              UH  UH, Germany, University of Hohenheim    3088       yes
# 255              UH  UH, Germany, University of Hohenheim    3255       yes
#
#      GeneticGroup
# 0          Iodent
# 1           Other
# 2           Other
# 3           Other
# 4           Other
# ..            ...
# 251     Lancaster
# 252         Other
# 253         Other
# 254         Other
# 255         Other
#
# [256 rows x 37 columns]}
# Sheet: Environment, Info: {'num_rows': 0, 'num_columns': 3, 'data_pivot': (0, 0), 'data': Empty DataFrame
# Columns: [studyId, envParam, envParamValue]
# Index: []}
# Sheet: Observation Unit, Info: {'num_rows': 0, 'num_columns': 7, 'data_pivot': (0, 0), 'data': Empty DataFrame
# Columns: [studyId, biologicalMaterialId, obsUnitId, obsUnitType, externalId, spatialDistribution, obsUnitFactorValue]
# Index: []}
# Sheet: Experimental Factor, Info: {'num_rows': 1, 'num_columns': 4, 'data_pivot': (0, 0), 'data':    studyId expeFactorType                                     expeFactorDesc  \
# 0      NaN       watering  targeted irrigation along the cycle (watered) ...
#
#   expeFactorValues
# 0  watered;rainfed  }
# Sheet: Event, Info: {'num_rows': 0, 'num_columns': 6, 'data_pivot': (0, 0), 'data': Empty DataFrame
# Columns: [studyId, obsUnitId, eventType, eventAccNumber, eventDesc, eventDate]
# Index: []}
# Sheet: Sample, Info: {'num_rows': 0, 'num_columns': 7, 'data_pivot': (0, 0), 'data': Empty DataFrame
# Columns: [obsUnitId, sampleId, developmentStage, anatomicalEntity, sampleDesc, collectionDate, externalId]
# Index: []}
# Sheet: Observed Variable, Info: {'num_rows': 104, 'num_columns': 17, 'data_pivot': (0, 0), 'data':      studyId variableId                                       variableName  \
# 0        NaN     Tnight                                  Night temperature
# 1        NaN       Ri_w                                    Solar radiation
# 2        NaN        Psi                               Soil water potential
# 3        NaN      Check  microplot altered by environmental measure (so...
# 4        NaN       Tmax                            Maximum air temperature
# ..       ...        ...                                                ...
# 99       NaN        W11                          leaf width of the leaf 11
# 100      NaN        W12                          leaf width of the leaf 12
# 101      NaN        W13                          leaf width of the leaf 13
# 102      NaN        W14                          leaf width of the leaf 14
# 103      NaN        W15                          leaf width of the leaf 15
#
#     variableAccNumber                traitName traitEntity  \
# 0        EIPO:0000001    Night air temperature         Air
# 1        EIPO:0000002          Solar radiation         Sun
# 2        EIPO:0000003     Soil water potential        Soil
# 3        EIPO:0000004    Experimental practice        Soil
# 4        EIPO:0000005  Maximal air temperature         Air
# ..                ...                      ...         ...
# 99                NaN               Leaf width        Leaf
# 100               NaN               Leaf width        Leaf
# 101               NaN               Leaf width        Leaf
# 102               NaN               Leaf width        Leaf
# 103               NaN               Leaf width        Leaf
#
#      traitEntityAccessionNumber traitCharacteristic  \
# 0                           NaN         Temperature
# 1                           NaN           Radiation
# 2                           NaN     Water potential
# 3                           NaN          Compaction
# 4                           NaN         Temperature
# ..                          ...                 ...
# 99                          NaN               Width
# 100                         NaN               Width
# 101                         NaN               Width
# 102                         NaN               Width
# 103                         NaN               Width
#
#      traitCharacteristicAccessionNumber  traitAccNumber  \
# 0                                   NaN    EIPO:0000006
# 1                                   NaN    EIPO:0000007
# 2                                   NaN    EIPO:0000008
# 3                                   NaN    EIPO:0000009
# 4                                   NaN    EIPO:0000010
# ..                                  ...             ...
# 99                                  NaN  CO_322:0000026
# 100                                 NaN  CO_322:0000026
# 101                                 NaN  CO_322:0000026
# 102                                 NaN  CO_322:0000026
# 103                                 NaN  CO_322:0000026
#
#                               methodName methodAccNumber  \
# 0          Night temperature measurement    EIPO:0000011
# 1            Solar radiation measurement    EIPO:0000012
# 2       Soil water potential measurement    EIPO:0000013
# 3                  Compaction estimation    EIPO:0000014
# 4    Maximum air temperature measurement    EIPO:0000015
# ..                                   ...             ...
# 99                Leaf width measurement  CO_322:0000268
# 100               Leaf width measurement  CO_322:0000268
# 101               Leaf width measurement  CO_322:0000268
# 102               Leaf width measurement  CO_322:0000268
# 103               Leaf width measurement  CO_322:0000268
#
#                                             methodDesc methodRef  \
# 0    Mean temperature (°C) during night (by conside...       NaN
# 1                               Intercepted radiation.       NaN
# 2        Average soil water potential, at three depths       NaN
# 3                                                  NaN       NaN
# 4                                 Measured temperature       NaN
# ..                                                 ...       ...
# 99                                                 NaN       NaN
# 100                                                NaN       NaN
# 101                                                NaN       NaN
# 102                                                NaN       NaN
# 103                                                NaN       NaN
#
#            scaleName  scaleAccNumber  timeScale
# 0    Celsius degrees    EIPO:0000016        NaN
# 1              W.m-2    EIPO:0000017        NaN
# 2             m3.m-3    EIPO:0000018        NaN
# 3    Celsius degrees    EIPO:0000016        NaN
# 4    Celsius degrees    EIPO:0000016        NaN
# ..               ...             ...        ...
# 99                cm  CO_322:0000348        NaN
# 100               cm  CO_322:0000348        NaN
# 101               cm  CO_322:0000348        NaN
# 102               cm  CO_322:0000348        NaN
# 103               cm  CO_322:0000348        NaN
#
# [104 rows x 17 columns]}

# %%
import pandas as pd 

example_files = [os.path.join(base_path, 'test_data/example_01_v1.1_ext.xlsx'),
                     os.path.join(base_path, 'test_data/example_02_v1.1_ext.xlsx'),
                     os.path.join(base_path, 'test_data/example_01_v1.2.xlsx'),
                     os.path.join(base_path, 'test_data/example_02_v1.2.xlsx')]
    

picked_example = example_files[2]

# Select Investigation Sheet
df = pd.read_excel(picked_example, sheet_name='Investigation')

# Get Colors of Fonts and Backgrounds
from openpyxl import load_workbook
wb = load_workbook(picked_example)
ws = wb['Investigation']
font_colors = {}
bg_colors = {}
for row in ws.iter_rows(min_row=1, max_row=ws.max_row, min_col=1, max_col=ws.max_column):
    for cell in row:
        font_colors[cell.coordinate] = cell.font.color.rgb if cell.font.color else None
        bg_colors[cell.coordinate] = cell.fill.fgColor.rgb if cell.fill.fgColor else None

bg_colors
# Out:
# {'A1': '00000000',
#  'B1': '00000000',
#  'C1': '00000000',
#  'D1': '00000000',
#  'E1': '00000000',
#  'F1': '00000000',
#  'G1': '00000000',
#  'H1': '00000000',
#  'I1': '00000000',
#  'A2': '00000000',
#  'B2': '00000000',
#  'C2': '00000000',
#  'D2': '00000000',
#  'E2': '00000000',
#  'F2': '00000000',
#  'G2': '00000000',
#  'H2': '00000000',
#  'I2': '00000000',
#  'A3': '00000000',
#  'B3': '00000000',
#  'C3': '00000000',
#  'D3': '00000000',
#  'E3': '00000000',
#  'F3': '00000000',
#  'G3': '00000000',
#  'H3': '00000000',
#  'I3': '00000000',
#  'A4': '00000000',
#  'B4': '00000000',
#  'C4': '00000000',
#  'D4': '00000000',
#  'E4': '00000000',
#  'F4': '00000000',
#  'G4': '00000000',
#  'H4': '00000000',
#  'I4': '00000000',
#  'A5': '00000000',
#  'B5': '00000000',
#  'C5': '00000000',
#  'D5': '00000000',
#  'E5': '00000000',
#  'F5': '00000000',
#  'G5': '00000000',
#  'H5': '00000000',
#  'I5': '00000000',
#  'A6': '00000000',
#  'B6': '00000000',
#  'C6': '00000000',
#  'D6': '00000000',
#  'E6': '00000000',
#  'F6': '00000000',
#  'G6': '00000000',
#  'H6': '00000000',
#  'I6': '00000000'}
