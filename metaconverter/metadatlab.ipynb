# %%
import pandas as pd 
import os
from collections import defaultdict # Dont know if nec


example = "../data/metadata/HyPlant_Metadata_MIAFPE.xlsx"
ontology_config = ""


df = pd.read_excel(example, sheet_name=None)

""" 
Each sheet is a class
Each Colum is a property

So every Sheet by itself is a graph with the sheet entity in its center.


Input: Excel(Checklist), Configuration of the Ontologies to load / Onto-File -> Create a new one for this specific Metadata Schema

Output

"""


# Get all thhe sheets:

sheets = [sh for sh in df.keys()]
sheets
# Out:
# ['Investigation',
#  'Investigation_copy',
#  'Study',
#  'Person',
#  'Observation Unit',
#  'Observed Variable',
#  'Biological Material',
#  'Data file',
#  'Sensor',
#  'Platform',
#  'Environment',
#  'Exp. Factor',
#  'Event',
#  'Sample',
#  'Appendix I - Environment',
#  'Appendix II - Exp. Factors']
